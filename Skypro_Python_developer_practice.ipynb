# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexR9AZ/Python_mix/blob/main/Skypro_Python_developer_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Шаг 1 - Print

# %% [markdown]
# Именно с print многие начинают свое знакомство с Python, выводя на экран заветную фразу Hello, World!
#
# Print - это функция, с помощью которой можно вывести информацию на экран.
#
# Синтаксис:

# %%
print()  # выведет пустую строку

# %%
print("Напечатали и забыли")  # выведет на экран все, что заключено в ""

# %% [markdown]
# ****Задание****
#
# Выведите "Это моя первая программа”

# %%
# Исходный код
print()
# Out:
# Это моя первая программа

# %% [markdown]
# # Шаг 2 - Print

# %% [markdown]
# Если необходимо вывести на экран несколько строк - используйте print для каждой из них.

# %% [markdown]
# ****Задание****
#
# Выведите:
#
# "Это моя первая программа"
#
# "Я люблю котов"
#
# "Не знаю, что еще сказать"

# %%
# Исходный код
print()
print()
print()

# %% [markdown]
# # Шаг 3 - Переменная

# %% [markdown]
# Переменная — это коробка, в которой лежат данные. У переменной есть:
#
# - имя
# - значение
# - тип
#
# Например:

# %%
name = "Александр"

# %% [markdown]
# где name - это имя переменной, Александр - это значение переменной, о типах переменных мы поговорим чуть позже.
#
# Обратите внимание, что текстовые значения переменных записываются в кавычках.
#
# Еще примеры:

# %%
profession = "Python-разработчик"
language = "Python"
duration = "10 months"

# %% [markdown]
# Теперь с помощью функции print мы можем выводить на экран значения переменных:

# %%
print(profession)  # выведет на экран Python-разработчик
print(language)  # выведет на экран Python
print(duration)  # выведет на экран 10 months

# %% [markdown]
# ****Задание****
#
# Создайте переменную line, задайте ей значение "Я изучаю питон" и выведите это значение на экран.

# %%
# Исходный код

line = ...

print()

# %% [markdown]
# # Шаг 4 - Переменная

# %% [markdown]
# Теперь поговорим про типы переменных. Рассмотрим два самых распространенных из них:
#
# **str** - это строковый тип данных, иначе говоря, это текст. Все наши переменные в прошлых заданиях было типа str. Особенность такого типа - это запись в кавычках.
#
# **int** - это целочисленные значения. Они записываются с помощью цифр без кавычек.
#
# Примеры:

# %%
product = 'молоко'

priсe = 120

print(product, priсe)

# %% [markdown]
# ****Задание****
#
# Создайте переменные name, age, salary, присвоив им любые значения, но при условии, что name и salary - это текстовые переменные (str), а age - число (int). Затем выведите эти значения на экран.

# %%
# Исходный код

name = ...
age = ...
salary = ...
print()
print()
print()

# %% [markdown]
# # Шаг 5 - Арифметика

# %% [markdown]
# Переменные типа int можно использовать для арифметических вычислений. Например, мы может написать программу, которая просуммирует значения переменных и выдаст нам результат на экран.
#
# Как это реализуется:
#
# 1. Создать исходные данные типа int
# 2. Создать новую переменную, внутри которой будет результат вычислений.
# 3. Присвоить этой переменной результат вычисления. Например, суммы:

# %%
number_1 = 3
number_2 = 2
result = number_1 + number_2

print(result)

# %% [markdown]
# **Задание**
#
# У вас есть переменные со значениями формата int. Создайте еще одну переменную summ, положите туда сумму всех исходных данных и выведите значение переменной summ на экран.

# %%
# Исходный код

a = 10
b = 100
c = 1000

summ = a + ...

print(summ)

# %% [markdown]
# # Шаг 6 - Арифметика

# %% [markdown]
# В предыдущем задании мы выполняли сложение над переменным. Теперь рассмотрим и основные математические операции:
#
# Сложение → x + y
#
# Вычитание → x - y
#
# Умножение → x * y
#
# Деление → x / y

# %% [markdown]
# **Задание**
#
# Напишите программу, которая выполняет 4 основных действия над значениями a и b.
#
# Результат каждого действия вывести на новой строке в порядке: сложение, вычитание, умножение, деление

# %%
# Исходный код
a = 200
b = 100
summ = ...
difference = ...
product = ...
quotient = ...

print(summ, difference, product, quotient)

# %% [markdown]
# # Шаг 7 - Input

# %% [markdown]
# Мы уже изучили функцию print, которая выводит значения на экран (показывает данные пользователю). Теперь рассмотрим input - функция, которая принимает данные от пользователя.
#
# Пример использования:

# %%
name = input()  # в переменную name будет записано значение 
print(name)

# %% [markdown]
# **Задание**
#
# Написать программу, которая принимает значение имя пользователя с клавиатуры, а потом выводит на экран две строки. Пример вывода:
# Привет
# Артем

# %%
# Исходный код

name = ...

print("Привет")
print(...)

# %% [markdown]
# # Шаг 8 - Input

# %% [markdown]
# Функция Input по умолчанию все значения принимает в формате str.
#
# Как это работает.

# %%
priсe = input() 
# если ввести с клавиатуры, например, 3 
# то в переменной priсe будет текстовое значение "3"

# %% [markdown]
# Для арифметических действий такое значение мы уже использовать не сможем, поэтому надо изменить формат принимаемых данных. Для этого используется:

# %%
price = int(input()) # т.е. мы сразу переводим данные в формат числа.
print(price + 2)

# %% [markdown]
# **Задание**
#
# Получите у пользователя два значения: наименование продукта **product** (тест) и количество **amount** (число). Вывод не нужен, тренажер произведет скрытую проверку значений.

# %%
product = ...
amount = ...

# %% [markdown]
# # Шаг 9 - Условие

# %% [markdown]
# Оператор if (его иногда называют оператором ветвления или условным оператором) — основной инструмент выбора в Python. Проще говоря, он выбирает, какое действие следует выполнить, в зависимости от значения переменных в момент проверки условия.
#
# Операторы для сравнения:

# %%
a == b  # равно

a != b  # не равно 

a > b  # больше

a < b  # меньше

a >= b  # больше или равно

a <= b  # меньше или равно

# %% [markdown]
# ![Untitled (5).png](data:image/png;base64,...)

# %% [markdown]
# Пример, как использовать условия с числами:

# %%
a = 10
b = 20

if a < b:
    print("a меньше b")  # этот текст на экране появится только если выполнится условие

# %% [markdown]
# Еще пример, как условия могут применяться с текстовыми переменными:

# %%
name_1 = "Андрей"
name_2 = "Дмитрий"

if name_1 == name_2:
    print("Имена одинаковые")  # этот текст на экране появится только если выполнится условие

# %% [markdown]
# **Задание**
#
# Напишите программу, которая:
#
# - получает от пользователя его возраст
# - записывает значение в переменную age (тип данных int)
# - проводит сравнение, есть ли пользователю 18 лет (больше или равно 18)
# - выводит на экран сообщение “Вам доступна регистрация на сайте”

# %%
# Исходный код
age = ...

if ...:
    ...

# %% [markdown]
# # Шаг 10 - Условие

# %% [markdown]
# Теперь ознакомимся с конструкцией if else.
#
# В предыдущих примерах у нас проверялось условие, а сообщение на экран выводилось только при выполнении условия. Оператор else (с англ. иначе) поможет выполнить какие-либо действия, если условие не выполнилось, т.е. иной вариант.

# %% [markdown]
# ![02aa09d4603d90a81a8d541945d021af.png](data:image/png;base64,...)

# %% [markdown]
# **Задание**
#
# Дополните предыдущую программу выводом текста "Вы можете находиться на сайте как гость", если возраст пользователя менее 18 лет.

# %%
age = int(input())

if age >= 18:
    print("Вам доступна регистрация на сайте")
...

# %% [markdown]
# # Применяем навыки + домашнее задание

# %% [markdown]
# Программа принимает три значения по очереди:
#
# first - это первое число
#
# symbol - это арифметический знак (это может быть + - * /)
#
# second - это второе число

# %%
first = int(input())  # принимает первое число
symbol = input()  # принимает арифметический знак
second = int(input())  # принимает второе число

if symbol == "+":  # проверяется условие: равняется ли наш арифметический знак плюсом
    result = first + second  # если условие выполняется, первое и второе число складываем
if symbol == "-":  # проверяется условие: равняется ли наш арифметический знак минусом
    result = first - second  # если условие выполняется, из первого числа вычитаем второе
if symbol == "*":  # проверяется условие: равняется ли наш арифметический знак знаком умножения
    result = first * second  # если условие выполняется, первое и второе число умножаются
if symbol == "/":  # проверяется условие: равняется ли наш арифметический знак знаком деления
    result = first / second  # если условие выполняется, первое число делится на второе

# выводим на экран первое число, затем арифметический знак, затем второе число, затем знак равенства и результат вычислений
print(first, symbol, second, "=", result)

# %% [markdown]
# Запустите эту программу и предложите ей значения: 12 / 0
#
# **Задание**
#
# Допишите условие программы так, чтоб при делении на 0 выводилось сообщение "Делить на 0 нельзя"
